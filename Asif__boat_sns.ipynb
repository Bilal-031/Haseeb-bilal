# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Boat load data set

# %%
boat = sns.load_dataset('titanic')
boat
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
boat.shape #shape
# Out:
# (891, 15)

# %%
boat.shape,boat.size #boat shape and size
# Out:
# ((891, 15), 13365)

# %%
boat.head(7) #boat head first seven values
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# ...

# %%
boat.tail(9) #boat data set last tail nine value
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 882  woman       False  NaN  Southampton    no   True
# 883    man        True  NaN  Southampton    no   True
# ...

# %%
boat.drop(['sex','age'],axis=1) #boat drop data sex and age
# Out:
#      survived  pclass  sibsp  parch     fare embarked   class    who  \
# 0           0       3      1      0   7.2500        S   Third    man
# 1           1       1      1      0  71.2833        C   First  woman
# 2           1       3      0      0   7.9250        S   Third  woman
# 3           1       1      1      0  53.1000        S   First  woman
# 4           0       3      0      0   8.0500        S   Third    man
# ..        ...     ...    ...    ...      ...      ...     ...    ...
# 886         0       2      0      0  13.0000        S  Second    man
# 887         1       1      0      0  30.0000        S   First  woman
# 888         0       3      1      2  23.4500        S   Third  woman
# 889         1       1      0      0  30.0000        C   First    man
# 890         0       3      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# ...

# %%
boat.describe() #boat dataset describe
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
boat.info() #boat data set info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
boat.groupby(['age','sex']).mean()        #boat data groupby and mean
# Out:
#               survived  pclass  sibsp  parch      fare  adult_male  alone
# age   sex
# 0.42  male         1.0     3.0    0.0    1.0    8.5167         0.0    0.0
# 0.67  male         1.0     2.0    1.0    1.0   14.5000         0.0    0.0
# 0.75  female       1.0     3.0    2.0    1.0   19.2583         0.0    0.0
# 0.83  male         1.0     2.0    0.5    1.5   23.8750         0.0    0.0
# 0.92  male         1.0     1.0    1.0    2.0  151.5500         0.0    0.0
# ...                ...     ...    ...    ...       ...         ...    ...
# 70.00 male         0.0     1.5    0.5    0.5   40.7500         1.0    0.5
# 70.50 male         0.0     3.0    0.0    0.0    7.7500         1.0    1.0
# 71.00 male         0.0     1.0    0.0    0.0   42.0792         1.0    1.0
# 74.00 male         0.0     3.0    0.0    0.0    7.7750         1.0    1.0
# 80.00 male         1.0     1.0    0.0    0.0   30.0000         1.0    1.0
#
# [145 rows x 7 columns]

# %%
boat[boat['age']<2] #boat age less than two
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 381         1       3  female  1.00      0      2   15.7417        C   Third
# 386         0       3    male  1.00      5      2   46.9000        S   Third
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 788         1       3    male  1.00      1      2   20.5750        S   Third
# ...

# %%
boat[(boat['age']<3) & (boat['pclass']<3)] #boat age lessthan three & boat pclass lessthan three show
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# 297         0       1  female  2.00      1      2  151.5500        S   First
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 340         1       2    male  2.00      1      1   26.0000        S  Second
# 530         1       2  female  2.00      1      1   26.0000        S  Second
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 827         1       2    male  1.00      0      2   37.0042        C  Second
# 831         1       2    male  0.83      1      1   18.7500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 78   child       False  NaN  Southampton   yes  False
# 183  child       False    F  Southampton   yes  False
# ...

# %% [markdown]
# #### Boat age less than five &boat clss lessthan five and groupby mean

# %%
boat[(boat['age']<5) & (boat['pclass']<5)].groupby(['age','class']).mean()
# Out:
#              survived  pclass     sibsp     parch        fare  adult_male  \
# age  class
# 0.42 First        NaN     NaN       NaN       NaN         NaN         NaN
#      Second       NaN     NaN       NaN       NaN         NaN         NaN
#      Third   1.000000     3.0  0.000000  1.000000    8.516700         0.0
# 0.67 First        NaN     NaN       NaN       NaN         NaN         NaN
#      Second  1.000000     2.0  1.000000  1.000000   14.500000         0.0
#      Third        NaN     NaN       NaN       NaN         NaN         NaN
# 0.75 First        NaN     NaN       NaN       NaN         NaN         NaN
#      Second       NaN     NaN       NaN       NaN         NaN         NaN
#      Third   1.000000     3.0  2.000000  1.000000   19.258300         0.0
# 0.83 First        NaN     NaN       NaN       NaN         NaN         NaN
#      Second  1.000000     2.0  0.500000  1.500000   23.875000         0.0
# ...

# %%
boat[(boat['age']<3) & (boat['sex']=='female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 297         0       1  female  2.00      1      2  151.5500        S   First
# 381         1       3  female  1.00      0      2   15.7417        C   Third
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 479         1       3  female  2.00      0      1   12.2875        S   Third
# 530         1       2  female  2.00      1      1   26.0000        S  Second
# 642         0       3  female  2.00      3      2   27.9000        S   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 119  child       False  NaN  Southampton    no  False
# ...

# %%
boat[(boat['age']<3) & (boat['sex']== 'female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 297         0       1  female  2.00      1      2  151.5500        S   First
# 381         1       3  female  1.00      0      2   15.7417        C   Third
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 479         1       3  female  2.00      0      1   12.2875        S   Third
# 530         1       2  female  2.00      1      1   26.0000        S  Second
# 642         0       3  female  2.00      3      2   27.9000        S   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 119  child       False  NaN  Southampton    no  False
# ...

# %%
boat.to_csv
# Out:
# <bound method NDFrame.to_csv of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...
